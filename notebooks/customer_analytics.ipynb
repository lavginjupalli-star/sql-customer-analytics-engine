# %% [markdown]
# # Customer Analytics
#
# ⚠️ Ensure load_data.py and run_all_analyses.py have been executed before opening this notebook.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../results/01_monthly_revenue.csv')
plt.figure(figsize=(10,5))
plt.plot(df['month'],df['revenue'])
plt.xticks(rotation=45)
plt.savefig('../screenshots/revenue.png')

# %% [markdown]
# ## Key Findings
# Observed insights from this analysis:
# - Revenue grows over time
# - Retention drops significantly
# - High-value customers dominate revenue
